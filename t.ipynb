# %%
import pandas as pd

# %%
df = pd.read_excel('消费记录.xlsx')

# %%
df[['餐饮', '学习用品']] = df[['餐饮', '学习用品']].fillna(0)
df
# Out:
#                 金额\n日期    餐饮  学习用品   电费    交通   零食   其他  Unnamed: 7  \
# 0           2025-09-01  10.9   0.0  0.0  17.0  0.0  0.0         NaN
# 1           2025-09-02  23.0   0.0  0.0   0.0  5.0  1.0         NaN
# 2           2025-09-03  12.0   0.0  NaN   NaN  5.0  NaN         NaN
# 3           2025-09-04   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 4           2025-09-05   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 5           2025-09-06   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 6           2025-09-07   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 7           2025-09-08   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 8           2025-09-09   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 9           2025-09-10   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 10                 NaT   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 11          2025-09-11   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# 12          2025-09-12   0.0   0.0  NaN   NaN  NaN  NaN         NaN
# ...
